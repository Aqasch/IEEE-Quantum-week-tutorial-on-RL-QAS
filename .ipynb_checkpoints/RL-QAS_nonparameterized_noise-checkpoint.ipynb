# %% [markdown]
# # RL-❗️QAS: <ins>R</ins>einforcement <ins>L</ins>earning for noisy <ins>Q</ins>uantum <ins>A</ins>rchitecture <ins>S</ins>earch
#
# In the noiseless setting, the RL agent evaluates a candidate circuit by comparing its output state with the target Bell or GHZ state. In a realistic setting, gates and measurements are imperfect, so the circuit output is generally a **mixed state** rather than a pure state.
#
# We model noise as a quantum channel $\mathcal{E}$ applied during circuit execution:
#
# $$\rho_{\mathrm{out}} =
# \mathcal{E}_{L}
# \circ \mathcal{U}_{L}
# \circ \cdots
# \circ
# \mathcal{E}_{1}
# \circ \mathcal{U}_{1}
# \left(\rho_{\mathrm{in}}\right),$$
#
# where $\mathcal{U}_{\ell}$ is the ideal operation at step $\ell$, $\mathcal{E}_{\ell}$ is its associated noise channel, and $\rho$ is a density matrix.
#
# The RL environment therefore becomes noise-aware: after an action appends a gate, the simulator applies both the intended gate and its noise channel. The reward can still be based on target-state fidelity, but it is now evaluated using the noisy output state:
#
# $$
# F(\rho_{\mathrm{out}}, \lvert \psi_{\mathrm{target}}\rangle)
# =
# \langle \psi_{\mathrm{target}} \rvert
# \rho_{\mathrm{out}}
# \lvert \psi_{\mathrm{target}}\rangle.
# $$
#
# A circuit is successful when it prepares a state that remains close to the target **despite accumulated noise**, rather than only under ideal simulation

# %% [markdown]
# ## RL-QAS effected by the following noise types
#
# <p align="center">
#   <img src="RL-QAS_noise_type.png" alt="title">
# </p>

# %% [markdown]
# ## The framework is compromised!!
#
# <p align="center">
#   <img src="RL-QAS_noise.png" alt="title">
# </p>

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector, DensityMatrix, state_fidelity
import torch
import torch.nn as nn
import random
import copy
from collections import namedtuple
import numpy as np
from itertools import product

# %% [markdown]
# ## Import dependencies for noise modelling

# %%
from qiskit_aer.noise import NoiseModel, depolarizing_error, phase_damping_error

# %%
def dictionary_of_actions(num_qubits):
    """
    Creates dictionary of actions for system which steers positions of gates,
    and axes of rotations.
    """
    dictionary = dict()
    i = 0
         
    for c, x in product(range(num_qubits), range(num_qubits)):
        if c != x:
            dictionary[i] = [c, x, num_qubits, 0]
            i += 1
   
    """h  denotes rotation axis. 0, 1, 2 -->  X, Y, Z axes """
    for r, h in product(range(num_qubits),
                           range(0, 4)):
        dictionary[i] = [num_qubits, 0, r, h]
        i += 1
    return dictionary

# %% [markdown]
# ## The action space looks same!

# %%
dictionary_of_actions(2)
# Out:
# {0: [0, 1, 2, 0],
#  1: [1, 0, 2, 0],
#  2: [2, 0, 0, 0],
#  3: [2, 0, 0, 1],
#  4: [2, 0, 0, 2],
#  5: [2, 0, 0, 3],
#  6: [2, 0, 1, 0],
#  7: [2, 0, 1, 1],
#  8: [2, 0, 1, 2],
#  9: [2, 0, 1, 3]}

# %%
class RLQAS_Env:
    """
    RL-QAS environment for:
      - Bell state, 2 qubits: (|00> + |11>) / sqrt(2)
      - GHZ state,  3 qubits: (|000> + |111>) / sqrt(2)

    Noise models:
      "none"           : Ideal statevector simulation.
      "depolarizing"   : Depolarizing noise after each gate.
      "dephasing"      : Phase damping after each gate.
      "combined"       : Depolarizing followed by phase damping after each gate.

    Parameters:
      p_dep_1q   : Depolarizing strength after X, Y, Z, H.
      p_dep_2q   : Depolarizing strength after CX.
      p_deph_1q  : Phase-damping strength after X, Y, Z, H.
      p_deph_2q  : Phase-damping strength per qubit after CX.
    """

    def __init__(
        self,
        num_qubits=2,
        num_layers=4,
        fidelity_reward_scale=50.0,
        done_threshold=0.99,
        noise_model="none",
        p_dep_1q=0.001,
        p_dep_2q=0.01,
        p_deph_1q=0.001,
        p_deph_2q=0.01,
        device="cpu",
    ):

        if num_qubits not in [2, 3]:
            raise ValueError(
                "This example supports only 2-qubit Bell and 3-qubit GHZ targets."
            )

        valid_noise_models = {
            "none",
            "depolarizing",
            "dephasing",
            "combined",
        }

        if noise_model not in valid_noise_models:
            raise ValueError(
                f"noise_model must be one of {valid_noise_models}; "
                f"received '{noise_model}'."
            )

        self.num_qubits = num_qubits
        self.num_layers = num_layers
        self.device = torch.device(device)

        self.fidelity_reward_scale = fidelity_reward_scale
        self.done_threshold = done_threshold

        self.noise_model_name = noise_model
        self.p_dep_1q = p_dep_1q
        self.p_dep_2q = p_dep_2q
        self.p_deph_1q = p_deph_1q
        self.p_deph_2q = p_deph_2q

        self.state_size = (
            self.num_layers
            * self.num_qubits
            * (self.num_qubits + 4)
        )

        self.action_size = self.num_qubits * (self.num_qubits + 4)

        if self.num_qubits == 2:
            target_vector = np.array(
                [1, 0, 0, 1],
                dtype=complex,
            ) / np.sqrt(2)

        else:
            target_vector = np.array(
                [1, 0, 0, 0, 0, 0, 0, 1],
                dtype=complex,
            ) / np.sqrt(2)

        self.target_statevector = Statevector(target_vector)

        self.target_density_matrix = DensityMatrix(
            np.outer(target_vector, target_vector.conj())
        )

        self.aer_noise_model = self._build_noise_model()

        # Ideal case: use the statevector simulator.
        if self.noise_model_name == "none":
            self.sim = AerSimulator(method="statevector")

        # Noisy cases: use a density matrix because noise yields mixed states.
        else:
            self.sim = AerSimulator(
                method="density_matrix",
                noise_model=self.aer_noise_model,
            )

        self.state = None
        self.moments = None
        self.step_counter = None
        self.error = None
        self.prev_cost = None

    def _build_noise_model(self):
        """Create the requested gate-noise model."""

        if self.noise_model_name == "none":
            return None

        noise = NoiseModel()

        depol_1q = depolarizing_error(self.p_dep_1q, 1)
        depol_2q = depolarizing_error(self.p_dep_2q, 2)

        dephase_1q = phase_damping_error(self.p_deph_1q)

        # Independent phase damping on the two qubits involved in CX.
        dephase_2q = dephase_1q.tensor(dephase_1q)

        one_qubit_gates = ["x", "y", "z", "h"]
        two_qubit_gates = ["cx"]

        if self.noise_model_name == "depolarizing":
            noise.add_all_qubit_quantum_error(
                depol_1q,
                one_qubit_gates,
            )

            noise.add_all_qubit_quantum_error(
                depol_2q,
                two_qubit_gates,
            )

        elif self.noise_model_name == "dephasing":
            noise.add_all_qubit_quantum_error(
                dephase_1q,
                one_qubit_gates,
            )

            noise.add_all_qubit_quantum_error(
                dephase_2q,
                two_qubit_gates,
            )

        elif self.noise_model_name == "combined":
            combined_1q = depol_1q.compose(dephase_1q)
            combined_2q = depol_2q.compose(dephase_2q)

            noise.add_all_qubit_quantum_error(
                combined_1q,
                one_qubit_gates,
            )

            noise.add_all_qubit_quantum_error(
                combined_2q,
                two_qubit_gates,
            )

        return noise

    def reset(self):
        """Reset circuit state and return the flattened RL representation."""

        self.state = torch.zeros(
            (
                self.num_layers,
                self.num_qubits + 4,
                self.num_qubits,
            ),
            dtype=torch.float32,
        )

        self.moments = [0] * self.num_qubits
        self.step_counter = -1

        self.prev_cost = self._compute_fidelity()

        # Kept to match your original convention:
        # self.error actually stores fidelity.
        self.error = float(self.prev_cost)

        return self.state.reshape(-1).to(self.device)

    def step(self, action, train_flag=True):
        """
        action = [ctrl, targ, rot_qubit, rot_axis]

        rot_axis:
          0 -> X
          1 -> Y
          2 -> Z
          3 -> H
        """

        if isinstance(action, torch.Tensor):
            action = action.detach().cpu().tolist()

        ctrl = int(action[0])
        targ = int(action[1])
        rot_qubit = int(action[2])
        rot_axis = int(action[3])

        next_state = self.state.clone()
        self.step_counter += 1

        valid_cnot = (
            ctrl < self.num_qubits
            and targ < self.num_qubits
            and ctrl != targ
        )

        valid_oneq = (
            rot_qubit < self.num_qubits
            and 0 <= rot_axis < 4
        )

        if valid_oneq:
            gate_layer = self.moments[rot_qubit]

        elif valid_cnot:
            gate_layer = max(
                self.moments[ctrl],
                self.moments[targ],
            )

        else:
            gate_layer = 0

        if gate_layer >= self.num_layers:
            fidelity = self._compute_fidelity()

            self.prev_cost = fidelity
            self.error = float(fidelity)

            return (
                self.state.reshape(-1).to(self.device),
                torch.tensor(
                    0.0,
                    dtype=torch.float32,
                    device=self.device,
                ),
                True,
            )

        if valid_cnot:
            next_state[gate_layer, targ, ctrl] = 1.0

        if valid_oneq:
            oneq_row = self.num_qubits + rot_axis
            next_state[gate_layer, oneq_row, rot_qubit] = 1.0

        if valid_oneq:
            self.moments[rot_qubit] += 1

        elif valid_cnot:
            next_moment = max(
                self.moments[ctrl],
                self.moments[targ],
            ) + 1

            self.moments[ctrl] = next_moment
            self.moments[targ] = next_moment

        self.state = next_state

        fidelity = self._compute_fidelity()

        # Kept identical in meaning to your original code:
        # error stores fidelity.
        self.error = float(fidelity)

        reward = self._reward_from_fidelity(fidelity)
        self.prev_cost = fidelity

        done_success = fidelity >= self.done_threshold
        done_layers = self.step_counter >= self.num_layers - 1

        done = bool(done_success or done_layers)

        return (
            self.state.reshape(-1).to(self.device),
            torch.tensor(
                reward,
                dtype=torch.float32,
                device=self.device,
            ),
            done,
        )

    def _make_circuit(self):
        """Convert the RL tensor encoding into a QuantumCircuit."""

        circ = QuantumCircuit(self.num_qubits)

        state_np = self.state.detach().cpu().numpy()

        for layer in range(self.num_layers):

            cnot_block = state_np[
                layer,
                :self.num_qubits,
                :,
            ]

            targ_indices, ctrl_indices = np.where(cnot_block == 1.0)

            for targ, ctrl in zip(targ_indices, ctrl_indices):
                if ctrl != targ:
                    circ.cx(int(ctrl), int(targ))

            oneq_block = state_np[
                layer,
                self.num_qubits:self.num_qubits + 4,
                :,
            ]

            gate_rows, qubits = np.where(oneq_block == 1.0)

            for gate_row, qubit in zip(gate_rows, qubits):

                if gate_row == 0:
                    circ.x(int(qubit))

                elif gate_row == 1:
                    circ.y(int(qubit))

                elif gate_row == 2:
                    circ.z(int(qubit))

                elif gate_row == 3:
                    circ.h(int(qubit))

        return circ

    def _compute_fidelity(self):
        """
        Evaluate final target fidelity.

        Ideal case:
          statevector simulator + save_statevector.

        Noisy case:
          density-matrix simulator + save_density_matrix.
        """

        circ = self._make_circuit()

        if self.noise_model_name == "none":
            circ.save_statevector(label="final_state")

            result = self.sim.run(circ).result()

            evolved_state = Statevector(
                result.data(0)["final_state"]
            )

            fidelity = state_fidelity(
                evolved_state,
                self.target_statevector,
            )

        else:
            circ.save_density_matrix(label="final_state")

            result = self.sim.run(circ).result()

            evolved_state = DensityMatrix(
                result.data(0)["final_state"]
            )

            fidelity = state_fidelity(
                evolved_state,
                self.target_density_matrix,
            )

        return float(fidelity)

    def _reward_from_fidelity(self, x=None):
        """
        Original reward behavior retained:
        self.error stores fidelity.
        """

        scalar = 50

        if self.error >= self.done_threshold:
            rwd = scalar * self.error

        else:
            rwd = self.error

        return rwd

# %%
num_qubits, max_steps, num_episodes = 2, 4, 1000

"""
IDEAL
"""
env_noiseless = RLQAS_Env(num_qubits=num_qubits, num_layers=max_steps, noise_model="none",)

"""
Depolarizing
"""
env_depolarizing = RLQAS_Env(
    num_qubits=num_qubits,
    num_layers=max_steps,
    noise_model="depolarizing",
    p_dep_1q=0.001,
    p_dep_2q=0.01,
)

"""
Dephasing
"""
env_dephasing = RLQAS_Env(
    num_qubits=2,
    num_layers=4,
    noise_model="dephasing",
    p_deph_1q=0.002,
    p_deph_2q=0.01,
)

"""
Deplorizing & dephasing
"""
env_noise_combined = RLQAS_Env(
    num_qubits=2,
    num_layers=6,
    noise_model="combined",
    p_dep_1q=0.001,
    p_dep_2q=0.01,
    p_deph_1q=0.002,
    p_deph_2q=0.001,
    done_threshold=0.95,
)

# %% [markdown]
# ## Random search

# %%
environment_type_list = ["none", "deplorizing", "dephasing", "combined"]

environment_type = environment_type_list[3]

if environment_type == environment_type_list[0]:
    env = env_noiseless
    comment = "😇 Noiseless Mode Activated 😇"
elif environment_type == environment_type_list[1]:
    env = env_depolarizing
    comment = "😬 Depolarizing Noise Activated! Need to work harder! 😬"
elif environment_type == environment_type_list[2]:
    env = env_dephasing
    comment = "😬 Dephasing Noise Activated! Need to work harder! 😬"
elif environment_type == environment_type_list[3]:
    env = env_noise_combined
    comment = "😤 Both Noise Models Are Activated! Need to work much harder! 😤"

actions_dict = dictionary_of_actions(num_qubits)
num_actions = len(actions_dict)
random_search_fidelities = []

print('--------------------------')
print(comment)
print("RANDOM SEARHCING!")
print('--------------------------')
print()

for ep in range(num_episodes):
    # print(f"\n=== Episode {ep+1} ===")
    state = env.reset()
    # print("Initial fidelity:", env.prev_cost)

    for step in range(max_steps):
        # sample a random action index
        a_idx = random.randint(0, num_actions - 1)
        action = actions_dict[a_idx]

        # step in the environment
        next_state, reward, done = env.step(action)

        if done:
            # done should correspond to fidelity reaching 1 (or your threshold)
            break
    # print(f"  Episode {ep}: fidelity={env.prev_cost:.6f}, reward={reward.item():.4f}, done={done}")
    if ep % 10 == 0:
        print("Episode:", ep, "finished after", step+1, "steps.", "Final fidelity:", env.prev_cost)
    random_search_fidelities.append(env.prev_cost)
# Out:
# --------------------------
# 😤 Both Noise Models Are Activated! Need to work much harder! 😤
# RANDOM SEARHCING!
# --------------------------
#
# Episode: 0 finished after 4 steps. Final fidelity: 0.250000000624947
# Episode: 10 finished after 4 steps. Final fidelity: 0.2500000003427275
# Episode: 20 finished after 2 steps. Final fidelity: 0.9905222281850947
# Episode: 30 finished after 4 steps. Final fidelity: 0.0009985010150734559
# Episode: 40 finished after 4 steps. Final fidelity: 0.0027475000484900943
# Episode: 50 finished after 4 steps. Final fidelity: 0.2500000002799758
# Episode: 60 finished after 4 steps. Final fidelity: 0.2500000003427275
# Episode: 70 finished after 4 steps. Final fidelity: 0.25000000027997593
# Episode: 80 finished after 4 steps. Final fidelity: 0.2500000006549896
# Episode: 90 finished after 4 steps. Final fidelity: 0.25000000027997593
# Episode: 100 finished after 4 steps. Final fidelity: 0.2500000006549893
# Episode: 110 finished after 4 steps. Final fidelity: 0.002994752552340952
# Episode: 120 finished after 4 steps. Final fidelity: 0.25000000065498906
# Episode: 130 finished after 4 steps. Final fidelity: 0.2500000006249472
# Episode: 140 finished after 4 steps. Final fidelity: 0.25000000068365624
# Episode: 150 finished after 4 steps. Final fidelity: 0.2500000003955756
# Episode: 160 finished after 2 steps. Final fidelity: 0.9905222281850947
# Episode: 170 finished after 4 steps. Final fidelity: 0.4990014990179423
# Episode: 180 finished after 4 steps. Final fidelity: 0.0009985010150734563
# Episode: 190 finished after 4 steps. Final fidelity: 0.2500000006249471
# Episode: 200 finished after 4 steps. Final fidelity: 0.2500000002799758
# Episode: 210 finished after 4 steps. Final fidelity: 0.0009985010174440004
# Episode: 220 finished after 4 steps. Final fidelity: 0.4990014990179423
# Episode: 230 finished after 4 steps. Final fidelity: 0.2500000002799758
# Episode: 240 finished after 4 steps. Final fidelity: 0.49577219712774667
# Episode: 250 finished after 4 steps. Final fidelity: 0.005220025092400019
# Episode: 260 finished after 4 steps. Final fidelity: 0.005464805071839409
# Episode: 270 finished after 4 steps. Final fidelity: 0.4970052484653783
# Episode: 280 finished after 4 steps. Final fidelity: 0.0012476271458179348
# Episode: 290 finished after 4 steps. Final fidelity: 0.4967582431346239
# Episode: 300 finished after 4 steps. Final fidelity: 0.002501235446102313
# Episode: 310 finished after 4 steps. Final fidelity: 0.0009985010174440004
# Episode: 320 finished after 4 steps. Final fidelity: 0.2500000003427275
# Episode: 330 finished after 4 steps. Final fidelity: 0.25000000027997604
# Episode: 340 finished after 4 steps. Final fidelity: 0.25000000090057384
# Episode: 350 finished after 4 steps. Final fidelity: 0.4975000011133985
# Episode: 360 finished after 4 steps. Final fidelity: 0.005220025092400016
# Episode: 370 finished after 4 steps. Final fidelity: 0.2500000003955756
# Episode: 380 finished after 4 steps. Final fidelity: 0.49850349600224797
# Episode: 390 finished after 4 steps. Final fidelity: 0.0034886395516934964
# Episode: 400 finished after 4 steps. Final fidelity: 0.0009985010174440004
# Episode: 410 finished after 4 steps. Final fidelity: 0.2500000006836566
# Episode: 420 finished after 4 steps. Final fidelity: 0.25000000065498906
# Episode: 430 finished after 4 steps. Final fidelity: 0.2500000003427565
# Episode: 440 finished after 4 steps. Final fidelity: 0.0012476271241563433
# Episode: 450 finished after 4 steps. Final fidelity: 0.4990014990155719
# Episode: 460 finished after 2 steps. Final fidelity: 0.9905222281850947
# Episode: 470 finished after 4 steps. Final fidelity: 0.25000000019807156
# Episode: 480 finished after 4 steps. Final fidelity: 0.0032417578047784354
# Episode: 490 finished after 4 steps. Final fidelity: 0.005464805071839411
# Episode: 500 finished after 4 steps. Final fidelity: 0.4990014990002482
# Episode: 510 finished after 4 steps. Final fidelity: 0.003241757803421749
# Episode: 520 finished after 4 steps. Final fidelity: 0.4967582431346241
# Episode: 530 finished after 4 steps. Final fidelity: 0.25000000027997593
# Episode: 540 finished after 4 steps. Final fidelity: 0.25000000027997604
# Episode: 550 finished after 4 steps. Final fidelity: 0.4967582431346239
# Episode: 560 finished after 4 steps. Final fidelity: 0.49675824313453676
# Episode: 570 finished after 4 steps. Final fidelity: 0.0009985010150734559
# Episode: 580 finished after 4 steps. Final fidelity: 0.25000000068365613
# Episode: 590 finished after 4 steps. Final fidelity: 0.003241757803421749
# Episode: 600 finished after 4 steps. Final fidelity: 0.2500000006549895
# Episode: 610 finished after 4 steps. Final fidelity: 0.4960183386679562
# Episode: 620 finished after 4 steps. Final fidelity: 0.007667824885810139
# Episode: 630 finished after 4 steps. Final fidelity: 0.49875237289352864
# Episode: 640 finished after 4 steps. Final fidelity: 0.003241757804778438
# Episode: 650 finished after 4 steps. Final fidelity: 0.001993511548102291
# Episode: 660 finished after 4 steps. Final fidelity: 0.2499999999999991
# Episode: 670 finished after 4 steps. Final fidelity: 0.4947799762995186
# Episode: 680 finished after 4 steps. Final fidelity: 0.4987523728758422
# Episode: 690 finished after 4 steps. Final fidelity: 0.2500000001980712
# Episode: 700 finished after 4 steps. Final fidelity: 0.4967582431346244
# Episode: 710 finished after 4 steps. Final fidelity: 0.2500000002799757
# Episode: 720 finished after 4 steps. Final fidelity: 0.25000000090057406
# Episode: 730 finished after 3 steps. Final fidelity: 0.983117006197871
# Episode: 740 finished after 4 steps. Final fidelity: 0.4970052484653782
# Episode: 750 finished after 4 steps. Final fidelity: 0.2500000002799758
# Episode: 760 finished after 4 steps. Final fidelity: 0.4987523728975034
# Episode: 770 finished after 4 steps. Final fidelity: 0.2500000009005737
# Episode: 780 finished after 4 steps. Final fidelity: 0.25000000068365624
# Episode: 790 finished after 4 steps. Final fidelity: 0.4990014990179423
# Episode: 800 finished after 4 steps. Final fidelity: 0.0009985010150734563
# Episode: 810 finished after 4 steps. Final fidelity: 0.25000000065498873
# Episode: 820 finished after 4 steps. Final fidelity: 0.250000000683656
# Episode: 830 finished after 4 steps. Final fidelity: 0.2500000006549894
# Episode: 840 finished after 4 steps. Final fidelity: 0.25000000068365635
# Episode: 850 finished after 4 steps. Final fidelity: 0.25000000027997604
# Episode: 860 finished after 4 steps. Final fidelity: 0.4945351962649452
# Episode: 870 finished after 4 steps. Final fidelity: 0.9885526036367219
# Episode: 880 finished after 4 steps. Final fidelity: 0.2500000006249474
# Episode: 890 finished after 4 steps. Final fidelity: 0.0032417578047784354
# Episode: 900 finished after 4 steps. Final fidelity: 0.2500000009005737
# Episode: 910 finished after 4 steps. Final fidelity: 0.0009985010150734555
# Episode: 920 finished after 4 steps. Final fidelity: 0.4925747515580308
# Episode: 930 finished after 4 steps. Final fidelity: 0.49453519626491504
# Episode: 940 finished after 4 steps. Final fidelity: 0.4967582431346244
# Episode: 950 finished after 4 steps. Final fidelity: 0.2500000006549892
# Episode: 960 finished after 4 steps. Final fidelity: 0.4970052484653782
# Episode: 970 finished after 4 steps. Final fidelity: 0.4947799762995179
# Episode: 980 finished after 4 steps. Final fidelity: 0.005220025092400019
# Episode: 990 finished after 4 steps. Final fidelity: 0.4990014990155713

# %%
import matplotlib.pyplot as plt
plt.plot(fidelities, 'o', markersize = 1)
plt.ylabel('Fidelity at the end of an episode')
plt.xlabel('Episode')
plt.show()

# %% [markdown]
# ## Training the agent

# %%
num_qubits, max_steps, num_episodes = 2, 4, 5000

import torch.optim as optim

num_actions = len(actions_dict)
device = torch.device("cpu")


print('--------------------------')
if environment_type == environment_type_list[0]:
    env = env_noiseless
    comment = "😇 Noiseless Mode Activated 😇"
elif environment_type == environment_type_list[1]:
    env = env_depolarizing
    comment = "😬 Depolarizing Noise Activated! Need to work harder! 😬"
elif environment_type == environment_type_list[2]:
    env = env_dephasing
    comment = "😬 Dephasing Noise Activated! Need to work harder! 😬"
elif environment_type == environment_type_list[3]:
    env = env_noise_combined
    comment = "😤 Both Noise Models Are Activated! Need to work much harder! 😤"
print(comment)
print("SEARCHIGN WITH JUST ONE LAYER NEURAL NETWORK UNDER RL-FRAMEWORK!")
print('--------------------------')
print()

state_dim = env.state_size  # flattened state length
action_dim = num_actions    # discrete actions 0..9

# --- tiny DQN network ---
class DQN(nn.Module):
    def __init__(self, state_dim, action_dim, hidden_dim=64):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, hidden_dim),
            nn.LeakyReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(),
            nn.Linear(hidden_dim, action_dim)
        )

    def forward(self, x):
        return self.net(x)

q_net = DQN(state_dim, action_dim).to(device)
target_net = DQN(state_dim, action_dim).to(device)
target_net.load_state_dict(q_net.state_dict())
target_net.eval()

optimizer = optim.Adam(q_net.parameters(), lr=3e-4)
loss_fn = nn.MSELoss()

# --- simple replay buffer ---
replay_buffer = []
buffer_capacity = 10000
batch_size = 64
gamma = 0.99

def push_transition(transition):
    if len(replay_buffer) >= buffer_capacity:
        replay_buffer.pop(0)
    replay_buffer.append(transition)

def sample_batch():
    batch = random.sample(replay_buffer, batch_size)
    state_b, action_b, reward_b, next_state_b, done_b = zip(*batch)
    state_b = torch.stack(state_b)
    action_b = torch.tensor(action_b, dtype=torch.long, device=device)
    reward_b = torch.tensor(reward_b, dtype=torch.float32, device=device)
    next_state_b = torch.stack(next_state_b)
    done_b = torch.tensor(done_b, dtype=torch.float32, device=device)
    return state_b, action_b, reward_b, next_state_b, done_b

# --- epsilon-greedy parameters ---
epsilon_start = 1.0
epsilon_end = 0.05
epsilon_decay = 10000   # in steps
global_step = 0

def get_epsilon(step):
    return max(epsilon_end, epsilon_start - step / epsilon_decay)

def select_action(state_vec):
    global global_step
    epsilon = get_epsilon(global_step)
    global_step += 1
    if random.random() < epsilon:
        return random.randint(0, action_dim - 1)
    with torch.no_grad():
        q_values = q_net(state_vec.unsqueeze(0))
        return int(q_values.argmax(dim=1).item())

# --- training loop ---
max_steps_per_episode = max_steps
target_update_freq = 100  # episodes

episode_rewards = []
episode_final_fidelities = []
episode_final_epsilons = []
episode_num_gates = []  # total gates used in that episode

for ep in range(num_episodes):
    state = env.reset()                         # shape: [state_dim], already on device
    state = state.to(device)
    total_reward = 0.0
    total_gates = 0

    for t in range(max_steps_per_episode):
        # choose action index via epsilon-greedy
        a_idx = select_action(state)
        action = actions_dict[a_idx]

        # step environment
        next_state, reward_t, done = env.step(action)
        next_state = next_state.to(device)

        r = reward_t.item()
        total_reward += r

        # count how many gates are present in the circuit state after this step
        # (you can also use env.moments if you prefer; here we just count nonzeros)
        total_gates = int((env.state.numpy() != 0).sum())

        # store transition in replay buffer
        push_transition((
            state,
            a_idx,
            r,
            next_state,
            float(done)
        ))

        state = next_state

        # DQN update
        if len(replay_buffer) >= batch_size:
            s_b, a_b, r_b, ns_b, d_b = sample_batch()

            # current Q(s, a)
            q_values = q_net(s_b)
            q_sa = q_values.gather(1, a_b.unsqueeze(1)).squeeze(1)

            # target Q = r + gamma * max_a' Q_target(s', a') * (1 - done)
            with torch.no_grad():
                next_q_values = target_net(ns_b)
                max_next_q = next_q_values.max(dim=1)[0]
                target_q = r_b + gamma * max_next_q * (1.0 - d_b)

            loss = loss_fn(q_sa, target_q)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        if done:
            break #requires applicants to provide a

    # episode-level logging
    episode_rewards.append(total_reward)
    episode_final_fidelities.append(env.prev_cost)
    episode_num_gates.append(total_gates)
    episode_final_epsilons.append(get_epsilon(global_step))

    # update target network
    if (ep + 1) % target_update_freq == 0:
        target_net.load_state_dict(q_net.state_dict())

    if (ep + 1) % 10 == 0:
        print(f"Episode {ep+1:3d} | total reward = {total_reward:.3f} | "
              f"last fidelity = {env.prev_cost:.6f} | gates = {total_gates} | "
              f"epsilon = {episode_final_epsilons[-1]:.3f}")

print("Training finished.")

# quick greedy evaluation run
state = env.reset().to(device)
for t in range(max_steps_per_episode):
    with torch.no_grad():
        q_vals = q_net(state.unsqueeze(0))
        a_idx = int(q_vals.argmax(dim=1).item())
    action = actions_dict[a_idx]
    next_state, reward_t, done = env.step(action)
    state = next_state.to(device)
    print(f"Eval step {t+1}: action_id={a_idx}, action={action}, fidelity={env.prev_cost:.6f}, reward={reward_t.item():.3f}, done={done}")
    if done:
        break

# Now you can plot episode_rewards, episode_final_fidelities,
# episode_final_epsilons, episode_num_gates after training.
# Out:
# --------------------------
# 😤 Both Noise Models Are Activated! Need to work much harder! 😤
# SEARCHIGN WITH JUST ONE LAYER NEURAL NETWORK UNDER RL-FRAMEWORK!
# --------------------------
#
# Episode  10 | total reward = 1.495 | last fidelity = 0.495025 | gates = 4 | epsilon = 0.996
# Episode  20 | total reward = 1.000 | last fidelity = 0.497005 | gates = 4 | epsilon = 0.992
# Episode  30 | total reward = 1.495 | last fidelity = 0.496758 | gates = 4 | epsilon = 0.988
# Episode  40 | total reward = 1.250 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.984
# Episode  50 | total reward = 50.107 | last fidelity = 0.982140 | gates = 4 | epsilon = 0.980
# Episode  60 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.976
# Episode  70 | total reward = 0.252 | last fidelity = 0.001248 | gates = 4 | epsilon = 0.973
# Episode  80 | total reward = 1.003 | last fidelity = 0.002995 | gates = 4 | epsilon = 0.969
# Episode  90 | total reward = 0.998 | last fidelity = 0.497005 | gates = 4 | epsilon = 0.965
# Episode 100 | total reward = 1.493 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.961
# Episode 110 | total reward = 0.753 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.957
# Episode 120 | total reward = 0.753 | last fidelity = 0.002748 | gates = 4 | epsilon = 0.953
# Episode 130 | total reward = 1.496 | last fidelity = 0.496758 | gates = 4 | epsilon = 0.949
# Episode 140 | total reward = 1.492 | last fidelity = 0.494535 | gates = 4 | epsilon = 0.945
# Episode 150 | total reward = 1.247 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.941
# Episode 160 | total reward = 1.749 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.937
# Episode 170 | total reward = 0.748 | last fidelity = 0.496758 | gates = 4 | epsilon = 0.933
# Episode 180 | total reward = 1.497 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.930
# Episode 190 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.926
# Episode 200 | total reward = 1.002 | last fidelity = 0.005220 | gates = 4 | epsilon = 0.922
# Episode 210 | total reward = 1.000 | last fidelity = 0.001994 | gates = 4 | epsilon = 0.918
# Episode 220 | total reward = 0.999 | last fidelity = 0.498752 | gates = 4 | epsilon = 0.914
# Episode 230 | total reward = 0.508 | last fidelity = 0.005220 | gates = 4 | epsilon = 0.910
# Episode 240 | total reward = 1.248 | last fidelity = 0.498255 | gates = 4 | epsilon = 0.906
# Episode 250 | total reward = 1.249 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.902
# Episode 260 | total reward = 0.754 | last fidelity = 0.003735 | gates = 4 | epsilon = 0.898
# Episode 270 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.894
# Episode 280 | total reward = 0.258 | last fidelity = 0.002748 | gates = 4 | epsilon = 0.890
# Episode 290 | total reward = 0.753 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.886
# Episode 300 | total reward = 1.749 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.882
# Episode 310 | total reward = 0.754 | last fidelity = 0.003735 | gates = 4 | epsilon = 0.878
# Episode 320 | total reward = 1.495 | last fidelity = 0.497253 | gates = 4 | epsilon = 0.874
# Episode 330 | total reward = 1.746 | last fidelity = 0.497500 | gates = 4 | epsilon = 0.870
# Episode 340 | total reward = 0.506 | last fidelity = 0.005220 | gates = 4 | epsilon = 0.866
# Episode 350 | total reward = 0.752 | last fidelity = 0.001994 | gates = 4 | epsilon = 0.862
# Episode 360 | total reward = 1.250 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.858
# Episode 370 | total reward = 1.000 | last fidelity = 0.002748 | gates = 4 | epsilon = 0.854
# Episode 380 | total reward = 0.999 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.850
# Episode 390 | total reward = 1.248 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.846
# Episode 400 | total reward = 1.742 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.842
# Episode 410 | total reward = 1.989 | last fidelity = 0.494535 | gates = 4 | epsilon = 0.838
# Episode 420 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.834
# Episode 430 | total reward = 1.250 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.831
# Episode 440 | total reward = 0.998 | last fidelity = 0.494535 | gates = 4 | epsilon = 0.827
# Episode 450 | total reward = 1.248 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.823
# Episode 460 | total reward = 1.247 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.819
# Episode 470 | total reward = 0.505 | last fidelity = 0.005220 | gates = 4 | epsilon = 0.815
# Episode 480 | total reward = 1.748 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.811
# Episode 490 | total reward = 1.249 | last fidelity = 0.001248 | gates = 4 | epsilon = 0.807
# Episode 500 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.803
# Episode 510 | total reward = 1.002 | last fidelity = 0.002748 | gates = 4 | epsilon = 0.799
# Episode 520 | total reward = 0.751 | last fidelity = 0.001497 | gates = 4 | epsilon = 0.795
# Episode 530 | total reward = 0.998 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.791
# Episode 540 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.787
# Episode 550 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.783
# Episode 560 | total reward = 0.254 | last fidelity = 0.002748 | gates = 4 | epsilon = 0.780
# Episode 570 | total reward = 1.249 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.776
# Episode 580 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.772
# Episode 590 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.768
# Episode 600 | total reward = 1.249 | last fidelity = 0.003982 | gates = 4 | epsilon = 0.764
# Episode 610 | total reward = 0.754 | last fidelity = 0.003489 | gates = 4 | epsilon = 0.760
# Episode 620 | total reward = 1.247 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.756
# Episode 630 | total reward = 1.249 | last fidelity = 0.498752 | gates = 4 | epsilon = 0.752
# Episode 640 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.748
# Episode 650 | total reward = 1.000 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.744
# Episode 660 | total reward = 1.249 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.740
# Episode 670 | total reward = 0.751 | last fidelity = 0.001248 | gates = 4 | epsilon = 0.737
# Episode 680 | total reward = 49.776 | last fidelity = 0.990522 | gates = 2 | epsilon = 0.733
# Episode 690 | total reward = 0.751 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.729
# Episode 700 | total reward = 0.751 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.725
# Episode 710 | total reward = 0.501 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.721
# Episode 720 | total reward = 0.750 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.717
# Episode 730 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.713
# Episode 740 | total reward = 0.252 | last fidelity = 0.001248 | gates = 4 | epsilon = 0.709
# Episode 750 | total reward = 0.256 | last fidelity = 0.003489 | gates = 4 | epsilon = 0.705
# Episode 760 | total reward = 1.744 | last fidelity = 0.496758 | gates = 4 | epsilon = 0.701
# Episode 770 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.697
# Episode 780 | total reward = 0.754 | last fidelity = 0.003982 | gates = 4 | epsilon = 0.693
# Episode 790 | total reward = 0.501 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.690
# Episode 800 | total reward = 0.753 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.686
# Episode 810 | total reward = 0.750 | last fidelity = 0.498255 | gates = 4 | epsilon = 0.682
# Episode 820 | total reward = 1.248 | last fidelity = 0.498255 | gates = 4 | epsilon = 0.678
# Episode 830 | total reward = 1.741 | last fidelity = 0.496511 | gates = 4 | epsilon = 0.674
# Episode 840 | total reward = 1.741 | last fidelity = 0.496511 | gates = 4 | epsilon = 0.670
# Episode 850 | total reward = 0.997 | last fidelity = 0.496758 | gates = 4 | epsilon = 0.666
# Episode 860 | total reward = 1.992 | last fidelity = 0.497005 | gates = 4 | epsilon = 0.662
# Episode 870 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.658
# Episode 880 | total reward = 1.250 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.654
# Episode 890 | total reward = 0.754 | last fidelity = 0.003982 | gates = 4 | epsilon = 0.650
# Episode 900 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.647
# Episode 910 | total reward = 0.251 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.643
# Episode 920 | total reward = 1.000 | last fidelity = 0.001497 | gates = 4 | epsilon = 0.639
# Episode 930 | total reward = 1.249 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.635
# Episode 940 | total reward = 1.248 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.631
# Episode 950 | total reward = 1.250 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.627
# Episode 960 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.623
# Episode 970 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.619
# Episode 980 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.615
# Episode 990 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.611
# Episode 1000 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.607
# Episode 1010 | total reward = 1.249 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.603
# Episode 1020 | total reward = 1.495 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.599
# Episode 1030 | total reward = 0.502 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.595
# Episode 1040 | total reward = 0.751 | last fidelity = 0.001497 | gates = 4 | epsilon = 0.592
# Episode 1050 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.588
# Episode 1060 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.584
# Episode 1070 | total reward = 1.249 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.580
# Episode 1080 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.576
# Episode 1090 | total reward = 1.493 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.572
# Episode 1100 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.568
# Episode 1110 | total reward = 0.751 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.564
# Episode 1120 | total reward = 1.248 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.560
# Episode 1130 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.556
# Episode 1140 | total reward = 0.508 | last fidelity = 0.005215 | gates = 4 | epsilon = 0.552
# Episode 1150 | total reward = 1.002 | last fidelity = 0.005220 | gates = 4 | epsilon = 0.548
# Episode 1160 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.544
# Episode 1170 | total reward = 0.501 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.540
# Episode 1180 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.536
# Episode 1190 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.533
# Episode 1200 | total reward = 1.495 | last fidelity = 0.003242 | gates = 4 | epsilon = 0.529
# Episode 1210 | total reward = 0.254 | last fidelity = 0.002748 | gates = 4 | epsilon = 0.525
# Episode 1220 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.521
# Episode 1230 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.517
# Episode 1240 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.513
# Episode 1250 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.509
# Episode 1260 | total reward = 0.750 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.505
# Episode 1270 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.501
# Episode 1280 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.497
# Episode 1290 | total reward = 1.492 | last fidelity = 0.494535 | gates = 4 | epsilon = 0.493
# Episode 1300 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.489
# Episode 1310 | total reward = 0.503 | last fidelity = 0.001497 | gates = 4 | epsilon = 0.485
# Episode 1320 | total reward = 1.741 | last fidelity = 0.496511 | gates = 4 | epsilon = 0.481
# Episode 1330 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.477
# Episode 1340 | total reward = 1.991 | last fidelity = 0.496758 | gates = 4 | epsilon = 0.473
# Episode 1350 | total reward = 1.741 | last fidelity = 0.496511 | gates = 4 | epsilon = 0.469
# Episode 1360 | total reward = 1.001 | last fidelity = 0.003242 | gates = 4 | epsilon = 0.465
# Episode 1370 | total reward = 1.000 | last fidelity = 0.001994 | gates = 4 | epsilon = 0.461
# Episode 1380 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.457
# Episode 1390 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.453
# Episode 1400 | total reward = 0.750 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.449
# Episode 1410 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.445
# Episode 1420 | total reward = 1.496 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.441
# Episode 1430 | total reward = 1.000 | last fidelity = 0.001497 | gates = 4 | epsilon = 0.437
# Episode 1440 | total reward = 0.501 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.433
# Episode 1450 | total reward = 1.249 | last fidelity = 0.001248 | gates = 4 | epsilon = 0.429
# Episode 1460 | total reward = 1.249 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.425
# Episode 1470 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.421
# Episode 1480 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.417
# Episode 1490 | total reward = 1.494 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.413
# Episode 1500 | total reward = 1.249 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.409
# Episode 1510 | total reward = 1.494 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.405
# Episode 1520 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.401
# Episode 1530 | total reward = 0.501 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.397
# Episode 1540 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.393
# Episode 1550 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.389
# Episode 1560 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.385
# Episode 1570 | total reward = 49.776 | last fidelity = 0.990522 | gates = 2 | epsilon = 0.382
# Episode 1580 | total reward = 0.749 | last fidelity = 0.497500 | gates = 4 | epsilon = 0.378
# Episode 1590 | total reward = 1.494 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.374
# Episode 1600 | total reward = 1.747 | last fidelity = 0.498752 | gates = 4 | epsilon = 0.370
# Episode 1610 | total reward = 0.501 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.366
# Episode 1620 | total reward = 0.501 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.362
# Episode 1630 | total reward = 49.776 | last fidelity = 0.990522 | gates = 2 | epsilon = 0.358
# Episode 1640 | total reward = 1.745 | last fidelity = 0.496758 | gates = 4 | epsilon = 0.354
# Episode 1650 | total reward = 1.249 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.350
# Episode 1660 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.346
# Episode 1670 | total reward = 1.739 | last fidelity = 0.494291 | gates = 4 | epsilon = 0.343
# Episode 1680 | total reward = 0.751 | last fidelity = 0.001248 | gates = 4 | epsilon = 0.339
# Episode 1690 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.335
# Episode 1700 | total reward = 0.750 | last fidelity = 0.498752 | gates = 4 | epsilon = 0.331
# Episode 1710 | total reward = 1.748 | last fidelity = 0.498752 | gates = 4 | epsilon = 0.327
# Episode 1720 | total reward = 0.999 | last fidelity = 0.498752 | gates = 4 | epsilon = 0.323
# Episode 1730 | total reward = 1.498 | last fidelity = 0.498255 | gates = 4 | epsilon = 0.319
# Episode 1740 | total reward = 0.501 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.315
# Episode 1750 | total reward = 1.249 | last fidelity = 0.498752 | gates = 4 | epsilon = 0.311
# Episode 1760 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.307
# Episode 1770 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.303
# Episode 1780 | total reward = 1.249 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.299
# Episode 1790 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.295
# Episode 1800 | total reward = 1.249 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.291
# Episode 1810 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.287
# Episode 1820 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.283
# Episode 1830 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.279
# Episode 1840 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.275
# Episode 1850 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.271
# Episode 1860 | total reward = 0.501 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.267
# Episode 1870 | total reward = 1.247 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.263
# Episode 1880 | total reward = 0.751 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.259
# Episode 1890 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.255
# Episode 1900 | total reward = 0.501 | last fidelity = 0.001248 | gates = 4 | epsilon = 0.251
# Episode 1910 | total reward = 1.249 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.247
# Episode 1920 | total reward = 0.501 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.243
# Episode 1930 | total reward = 1.249 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.239
# Episode 1940 | total reward = 1.498 | last fidelity = 0.498752 | gates = 4 | epsilon = 0.236
# Episode 1950 | total reward = 1.494 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.232
# Episode 1960 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.228
# Episode 1970 | total reward = 1.497 | last fidelity = 0.498255 | gates = 4 | epsilon = 0.224
# Episode 1980 | total reward = 1.249 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.220
# Episode 1990 | total reward = 1.498 | last fidelity = 0.498255 | gates = 4 | epsilon = 0.216
# Episode 2000 | total reward = 0.751 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.212
# Episode 2010 | total reward = 0.751 | last fidelity = 0.001248 | gates = 4 | epsilon = 0.208
# Episode 2020 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.204
# Episode 2030 | total reward = 0.501 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.200
# Episode 2040 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.196
# Episode 2050 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.192
# Episode 2060 | total reward = 1.497 | last fidelity = 0.498255 | gates = 4 | epsilon = 0.188
# Episode 2070 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.184
# Episode 2080 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.180
# Episode 2090 | total reward = 1.249 | last fidelity = 0.498752 | gates = 4 | epsilon = 0.176
# Episode 2100 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.172
# Episode 2110 | total reward = 1.250 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.168
# Episode 2120 | total reward = 0.999 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.164
# Episode 2130 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.160
# Episode 2140 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.156
# Episode 2150 | total reward = 1.249 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.152
# Episode 2160 | total reward = 1.249 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.148
# Episode 2170 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.144
# Episode 2180 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.140
# Episode 2190 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.136
# Episode 2200 | total reward = 1.249 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.132
# Episode 2210 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.128
# Episode 2220 | total reward = 1.250 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.124
# Episode 2230 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.120
# Episode 2240 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.116
# Episode 2250 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.112
# Episode 2260 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.108
# Episode 2270 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.104
# Episode 2280 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.100
# Episode 2290 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.096
# Episode 2300 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.092
# Episode 2310 | total reward = 1.499 | last fidelity = 0.003242 | gates = 4 | epsilon = 0.088
# Episode 2320 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.084
# Episode 2330 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.080
# Episode 2340 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.076
# Episode 2350 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.072
# Episode 2360 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.068
# Episode 2370 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.064
# Episode 2380 | total reward = 1.250 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.060
# Episode 2390 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.056
# Episode 2400 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.052
# Episode 2410 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2420 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2430 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2440 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2450 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2460 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2470 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2480 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2490 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2500 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2510 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2520 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2530 | total reward = 0.002 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2540 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2550 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2560 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2570 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2580 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2590 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2600 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2610 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2620 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2630 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2640 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2650 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2660 | total reward = 1.746 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 2670 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2680 | total reward = 0.002 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2690 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2700 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2710 | total reward = 1.249 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 2720 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2730 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2740 | total reward = 1.749 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 2750 | total reward = 1.749 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 2760 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2770 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2780 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2790 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 2800 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2810 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2820 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 2830 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 2840 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2850 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2860 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2870 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2880 | total reward = 1.996 | last fidelity = 0.497500 | gates = 4 | epsilon = 0.050
# Episode 2890 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2900 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2910 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2920 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2930 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2940 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2950 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 2960 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2970 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2980 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 2990 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 3000 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 3010 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 3020 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 3030 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 3040 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 3050 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 3060 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 3070 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 3080 | total reward = 1.989 | last fidelity = 0.496758 | gates = 4 | epsilon = 0.050
# Episode 3090 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 3100 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 3110 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 3120 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 3130 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 3140 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 3150 | total reward = 1.000 | last fidelity = 0.001248 | gates = 4 | epsilon = 0.050
# Episode 3160 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 3170 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 3180 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 3190 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 3200 | total reward = 1.495 | last fidelity = 0.005465 | gates = 4 | epsilon = 0.050
# Episode 3210 | total reward = 1.499 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 3220 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 3230 | total reward = 1.000 | last fidelity = 0.001248 | gates = 4 | epsilon = 0.050
# Episode 3240 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 3250 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 3260 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 3270 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 3280 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 3290 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 3300 | total reward = 0.751 | last fidelity = 0.001248 | gates = 4 | epsilon = 0.050
# Episode 3310 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3320 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3330 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3340 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3350 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3360 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.050
# Episode 3370 | total reward = 0.751 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3380 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3390 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3400 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3410 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3420 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3430 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3440 | total reward = 1.250 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3450 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.050
# Episode 3460 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3470 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3480 | total reward = 1.001 | last fidelity = 0.001248 | gates = 4 | epsilon = 0.050
# Episode 3490 | total reward = 1.498 | last fidelity = 0.498503 | gates = 4 | epsilon = 0.050
# Episode 3500 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3510 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3520 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3530 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3540 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3550 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3560 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3570 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3580 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3590 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3600 | total reward = 1.250 | last fidelity = 0.001248 | gates = 4 | epsilon = 0.050
# Episode 3610 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3620 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3630 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3640 | total reward = 0.751 | last fidelity = 0.001248 | gates = 4 | epsilon = 0.050
# Episode 3650 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3660 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3670 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3680 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3690 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3700 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3710 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3720 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3730 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3740 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3750 | total reward = 1.748 | last fidelity = 0.498752 | gates = 4 | epsilon = 0.050
# Episode 3760 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3770 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3780 | total reward = 1.250 | last fidelity = 0.001248 | gates = 4 | epsilon = 0.050
# Episode 3790 | total reward = 1.748 | last fidelity = 0.498752 | gates = 4 | epsilon = 0.050
# Episode 3800 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3810 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3820 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3830 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3840 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3850 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3860 | total reward = 0.002 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 3870 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3880 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3890 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3900 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3910 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3920 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3930 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3940 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3950 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3960 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3970 | total reward = 1.749 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 3980 | total reward = 1.001 | last fidelity = 0.001497 | gates = 4 | epsilon = 0.050
# Episode 3990 | total reward = 1.748 | last fidelity = 0.498752 | gates = 4 | epsilon = 0.050
# Episode 4000 | total reward = 1.499 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 4010 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4020 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4030 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4040 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4050 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4060 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4070 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4080 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4090 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4100 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4110 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4120 | total reward = 1.499 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 4130 | total reward = 1.499 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 4140 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4150 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4160 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4170 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4180 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4190 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4200 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4210 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4220 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4230 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4240 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4250 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 4260 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4270 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4280 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4290 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4300 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4310 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4320 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4330 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4340 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4350 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4360 | total reward = 1.742 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 4370 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4380 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4390 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4400 | total reward = 0.501 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4410 | total reward = 1.250 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 4420 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4430 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4440 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4450 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4460 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4470 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4480 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4490 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4500 | total reward = 0.002 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4510 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4520 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4530 | total reward = 0.502 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4540 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4550 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4560 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4570 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4580 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4590 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4600 | total reward = 1.980 | last fidelity = 0.492575 | gates = 4 | epsilon = 0.050
# Episode 4610 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4620 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4630 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4640 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4650 | total reward = 1.989 | last fidelity = 0.496758 | gates = 4 | epsilon = 0.050
# Episode 4660 | total reward = 1.497 | last fidelity = 0.497005 | gates = 4 | epsilon = 0.050
# Episode 4670 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4680 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4690 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4700 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4710 | total reward = 1.000 | last fidelity = 0.250000 | gates = 4 | epsilon = 0.050
# Episode 4720 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4730 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4740 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4750 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4760 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4770 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4780 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4790 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4800 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4810 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4820 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4830 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4840 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4850 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4860 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4870 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4880 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4890 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4900 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4910 | total reward = 1.998 | last fidelity = 0.499001 | gates = 4 | epsilon = 0.050
# Episode 4920 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4930 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4940 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4950 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4960 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4970 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4980 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 4990 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Episode 5000 | total reward = 1.000 | last fidelity = 0.000999 | gates = 4 | epsilon = 0.050
# Training finished.
# Eval step 1: action_id=4, action=[2, 0, 0, 2], fidelity=0.499750, reward=0.500, done=False
# Eval step 2: action_id=7, action=[2, 0, 1, 1], fidelity=0.000500, reward=0.000, done=False
# Eval step 3: action_id=7, action=[2, 0, 1, 1], fidelity=0.499251, reward=0.499, done=False
# Eval step 4: action_id=7, action=[2, 0, 1, 1], fidelity=0.000999, reward=0.001, done=False

# %%
fig, ax = plt.subplots(1, 2, figsize = (9, 3), sharey = True)

ax[0].semilogy(episode_final_epsilons)
ax[0].set_ylabel('$\\epsilon$-decay')
ax[1].semilogy(episode_rewards)
ax[1].set_ylabel('Reward')
ax[0].set_xlabel('Episode')
ax[1].set_xlabel('Episode')
plt.show()

# %%
# fig, ax = plt.subplots(1, 2, figsize = (9, 3))

chunk_size = 100
threshold = 0.95  # or env.done_threshold if you prefer >= threshold as success

num_chunks = (num_episodes + chunk_size - 1) // chunk_size  # ceil

chunk_success_rates_agent = []
chunk_success_rates_random = []

for k in range(num_chunks):
    start = k * chunk_size
    end = min((k + 1) * chunk_size, num_episodes)

    # slice the fidelities for this chunk
    fidelities_chunk_agent = episode_final_fidelities[start:end]
    fidelities_chunk_random = random_search_fidelities[start:end]

    # count successes (agent)
    successes = sum(1 for f in fidelities_chunk_agent if f >= threshold)
    length = len(fidelities_chunk_agent)
    success_rate = successes / length if length > 0 else 0.0
    chunk_success_rates_agent.append(success_rate)

    # count successes (random)
    successes = sum(1 for f in fidelities_chunk_random if f >= threshold)
    length = len(fidelities_chunk_agent)
    success_rate = successes / length if length > 0 else 0.0
    chunk_success_rates_random.append(success_rate)
    

plt.plot(range(1, len(chunk_success_rates_agent)+1), chunk_success_rates_agent, '-o', markersize = 7, label = 'agent')
plt.plot(range(1, len(chunk_success_rates_random)+1), chunk_success_rates_random, '-x', markersize = 7, label = 'random')
plt.xlabel('Episode = Interval $\\times$ 100')
plt.ylabel('Success')
plt.legend()
plt.show()
